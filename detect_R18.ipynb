# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# !git checkout 9931f56
# %pip install -qr requirements.txt  # install
import os
import torch
import cv2
import numpy as np
from os import walk
from os.path import join
from datetime import datetime
from yolov5 import utils
display = utils.notebook_init()  # checks
import matplotlib.pyplot as plt
from google.colab import drive
from google.colab.patches import cv2_imshow
drive.mount('/content/gdrive')
import pandas as pd
# Out:
# YOLOv5 🚀 v6.1-105-g9931f56 torch 1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 38.7/78.2 GB disk)
# Mounted at /content/gdrive

# %%
'''
This sample code takes '/content/gdrive/MyDrive/AI_final_project' as the folder path to store R18_material.zip,
If the path used below is not your Google Drive path, please replace it with the path where you put R18_material.zip
'''
yourPath = '/content/gdrive/MyDrive/nipples/detection'

# %%
'''
Get the required dataset 
'''
zipPath = os.path.join(yourPath, 'R18_material.zip')
# !unzip $zipPath

# %%
'''
Fine-tune on our training datasets
'''
# !python train.py --img 448 --batch 64 --epochs 100 --data R18.yaml  --weights yolov5s.pt --cache --exist-ok

'''
Copy the best model parameters to your own drive
'''
savePath = yourPath + '/' 
# !cp '/content/yolov5/runs/train/exp/weights/best.pt' $savePath
# Out:
# ...
# train: weights=yolov5m.pt, cfg=, data=R18.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=100, batch_size=64, imgsz=448, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=True, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: ⚠️ YOLOv5 is out of date by 234 commits. Use `git pull` or `git clone https://github.com/ultralytics/yolov5` to update.
# YOLOv5 🚀 v6.1-105-g9931f56 torch 1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# ...

# %%
# !python detect.py --weights /content/yolov5/runs/train/exp/weights/best.pt --img 448 --conf 0.5 --save-txt --exist-ok --source /content/gdrive/MyDrive/nipples/test/84416051_002_8360.jpg
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/best.pt'], source=/content/gdrive/MyDrive/nipples/test/84416051_002_8360.jpg, data=data/coco128.yaml, imgsz=[448, 448], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=True, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=True, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-105-g9931f56 torch 1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model Summary: 290 layers, 20852934 parameters, 0 gradients
# image 1/1 /content/gdrive/MyDrive/nipples/test/84416051_002_8360.jpg: 448x352 1 18+, Done. (0.020s)
# Speed: 0.4ms pre-process, 20.1ms inference, 1.6ms NMS per image at shape (1, 3, 448, 448)
# Results saved to runs/detect/exp
# 3 labels saved to runs/detect/exp/labels
